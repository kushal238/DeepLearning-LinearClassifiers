# %% [markdown]
# # Imports

# %%
import random
import numpy as np
from data_process import get_FASHION_data, get_RICE_data
from scipy.spatial import distance
from models import Perceptron, SVM, Softmax, Logistic
from kaggle_submission import output_submission_csv
# %matplotlib inline


# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Loading Fashion-MNIST

# %%
TRAIN_IMAGES = 50000
VAL_IMAGES = 10000
normalize = True

# %%
data = get_FASHION_data(TRAIN_IMAGES, VAL_IMAGES, normalize=normalize)
X_train_fashion, y_train_fashion = data['X_train'], data['y_train']
X_val_fashion, y_val_fashion = data['X_val'], data['y_val']
X_test_fashion, y_test_fashion = data['X_test'], data['y_test']
n_class_fashion = len(np.unique(y_test_fashion))

# %% [markdown]
# # Loading Rice

# %%
# loads train / test / val splits of 80%, 20%, 20% 
data = get_RICE_data()
X_train_RICE, y_train_RICE = data['X_train'], data['y_train']
X_val_RICE, y_val_RICE = data['X_val'], data['y_val']
X_test_RICE, y_test_RICE = data['X_test'], data['y_test']
n_class_RICE = len(np.unique(y_test_RICE))

print("Number of train samples: ", X_train_RICE.shape[0])
print("Number of val samples: ", X_val_RICE.shape[0])
print("Number of test samples: ", X_test_RICE.shape[0])
# Out:
# Number of train samples:  10911
# Number of val samples:  3637
# Number of test samples:  3637

# %% [markdown]
# ### Accuracy

# %%
def get_acc(pred, y_test):
    return np.sum(y_test == pred) / len(y_test) * 100

# %% [markdown]
# # Perceptron

# %% [markdown]
# ## Training Perceptron on Fashion-MNIST

# %%
lr = 0.5
n_epochs = 20

percept_fashion = Perceptron(n_class_fashion, lr, n_epochs)
percept_fashion.train(X_train_fashion, y_train_fashion)

# %%
pred_percept = percept_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_fashion)))
# Out:
# The training accuracy is given by: 84.920000

# %% [markdown]
# ### Validating Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_fashion)))
# Out:
# The validation accuracy is given by: 83.230000

# %% [markdown]
# ### Testing Perceptron on Fashion-MNIST

# %%
pred_percept = percept_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_fashion)))
# Out:
# The testing accuracy is given by: 81.740000

# %% [markdown]
# ## Training Perceptron on Rice

# %%
lr = 0.5
n_epochs = 10

percept_RICE = Perceptron(n_class_RICE, lr, n_epochs)
percept_RICE.train(X_train_RICE, y_train_RICE)

# %%
pred_percept = percept_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_percept, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.844194

# %% [markdown]
# ### Validating Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_percept, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.807534

# %% [markdown]
# ### Testing Perceptron on Rice

# %%
pred_percept = percept_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_percept, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.752543

# %% [markdown]
# # Support Vector Machines (with SGD)

# %% [markdown]
# ## Training SVM on Fashion-MNIST

# %%
lr = 1
n_epochs = 67
reg_const = 0.05

svm_fashion = SVM(n_class_fashion, lr, n_epochs, reg_const)
svm_fashion.train(X_train_fashion, y_train_fashion)

# %%
pred_svm = svm_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_fashion)))
# Out:
# [-4.31131649e-17 -6.96283066e-16 -2.22773605e-16  8.55132243e-15
#   4.86712892e-16 -8.35396197e-16 -1.30031097e-14  3.82628507e-14
#   2.71663758e-14  5.73263748e-14 -7.08119785e-14 -8.75036221e-14
#  -1.29105615e-15  5.85855275e-14  3.94820177e-14  3.64622110e-14
#  -6.39151665e-14  1.32235272e-13  1.12973737e-13 -4.28515534e-14
#   8.78656081e-14  3.29630812e-14 -1.54567914e-14 -1.75321757e-14
#   5.09887688e-16 -1.60803426e-14 -8.97206920e-15  2.18767282e-15
#   1.95976679e-15 -4.45515805e-15  9.36812738e-15 -1.38653067e-14
#  -1.37636569e-16  1.77278814e-14  2.91323943e-14 -4.09245615e-14
#   8.53207638e-14  7.12361725e-14  6.88976343e-14 -4.08056167e-14
#   1.12694352e-13  1.16125705e-13 -7.97319899e-14  5.19057153e-14
#  -6.31894181e-14  1.42446197e-13  2.07531343e-13  4.05786551e-13
#  -1.64921659e-13 -4.82844342e-14 -2.43546694e-14  3.10808446e-14
#  -2.47956855e-14 -7.23976434e-15 -1.89723148e-14 -1.08627191e-14
#  -4.79094056e-15  3.15349913e-15 -7.82453213e-15 -4.99045250e-16
#   1.68648739e-14 -3.63731800e-14 -4.34083347e-14  1.88211402e-14
#   1.16415322e-15  8.32244496e-14 -7.99022359e-14 -3.98244993e-14
#   1.03298703e-14  4.61190552e-14 -6.98491931e-15  9.48858769e-14
#   2.12065743e-14  1.34140237e-13  1.40607881e-14 -8.86927864e-14
#   6.83797907e-15  7.53189511e-14 -8.32714875e-14  8.42788950e-15
#  -6.34248920e-14  1.12090248e-14  1.21138388e-14  9.55975632e-15
#   3.90401045e-15  9.59841207e-15 -1.48444057e-14 -2.81304136e-14
#   6.41488640e-15  2.97264364e-13 -4.93139396e-14 -1.46684158e-13
#  -2.02958290e-13 -4.43367298e-14  2.78674861e-15  1.26863142e-14
#   9.20863386e-17 -2.58796717e-14 -7.54982921e-14 -5.63593971e-14
#  -2.70145506e-14 -1.69503380e-13  1.69112866e-13 -1.12160023e-13
#   2.44945397e-13  1.83771647e-13  6.82888412e-15  4.35331060e-14
#   4.41041692e-14  1.25749011e-14  1.27998945e-15 -1.69017311e-14
#  -6.26176277e-15  9.93619409e-15 -2.57953303e-14  1.52337698e-14
#  -1.21149739e-13  1.11933218e-14  7.01285785e-14 -2.37786537e-13
#  -1.20608661e-13 -5.92660854e-14  3.14631166e-14 -6.39894893e-14
#  -6.46204512e-14  8.35169089e-14 -3.10734549e-15 -1.11090230e-13
#  -5.01520958e-14  1.32401681e-13  1.39347662e-13  1.33519507e-14
#  -2.78766947e-13  1.68051599e-13  4.95251129e-14  1.35240867e-13
#   2.14266294e-14  1.84547844e-14 -5.82315884e-14 -6.61479316e-15
#  -1.53265600e-14 -8.61482441e-15 -1.78300930e-14 -4.65461270e-14
#  -4.92320851e-15  3.20142135e-15 -1.30109186e-13 -2.33932269e-13
#  -3.46585693e-14 -7.15226633e-14 -1.31521460e-14  2.69309908e-14
#  -2.03918660e-13  1.37313805e-14  1.09735936e-13 -6.42444320e-15
#   4.34451408e-14 -8.77039952e-14  1.58871387e-13  9.90235094e-14
#  -2.75156253e-13  3.45954732e-14 -1.63282721e-15 -9.01059138e-14
#  -3.27560201e-16 -1.67398184e-14 -1.19577592e-14  2.28554953e-16
#   3.62017372e-14 -2.55899835e-14  2.56488875e-14 -1.90723242e-13
#  -1.17755690e-13 -1.17532295e-14  1.51825077e-13  6.89374247e-14
#   5.09652409e-14 -8.74649686e-15 -7.25836458e-14 -1.55895918e-14
#  -2.84375687e-13  4.33692549e-14 -1.13581677e-14 -2.22783569e-14
#   6.34486241e-15  9.88174520e-14 -3.49245965e-15 -2.68849476e-14
#  -2.89360571e-13  6.43427711e-14  6.78301149e-14 -2.13873363e-15
#   1.67040071e-13  6.71936107e-14 -8.30567615e-14  4.33237801e-14
#   6.00155925e-15 -2.08218864e-14 -3.33565708e-14  4.42070558e-14
#  -9.81221149e-14 -8.41239967e-14 -2.52327936e-14  5.50727464e-14
#  -6.44797638e-14  8.50360493e-14 -6.99250791e-14 -2.96292910e-13
#   1.21272876e-13  1.08789777e-14 -2.03127115e-14  9.24720212e-14
#   2.11312567e-14 -1.87515070e-14  2.00843715e-13  1.03117657e-13
#  -2.91038305e-15  4.83669282e-14  2.60428124e-14 -1.09043583e-13
#  -1.32978641e-13 -5.76484638e-14 -4.49455939e-14  1.58215130e-14
#  -4.90807395e-16 -3.04253867e-14 -3.71289488e-14  5.20401500e-14
#   1.19836301e-13 -8.44093506e-14  2.19574758e-13  4.14435135e-13
#  -6.93705715e-14 -4.36295977e-14  2.97254132e-14 -1.04449498e-13
#  -5.20628873e-15  2.38760549e-13  1.68459451e-13 -4.61284344e-14
#   7.19313675e-14 -1.69643499e-13 -8.51810000e-14 -6.52883614e-14
#   9.90542048e-14 -8.88002205e-14 -2.14487841e-13  6.00368821e-14
#  -2.67712039e-13 -8.48740456e-14 -1.17908030e-13  2.26622809e-14
#   7.83171750e-15  4.13633572e-14  1.69215753e-15 -1.48736490e-14
#  -8.48308446e-14  2.65140727e-13 -1.84099349e-13  1.79572908e-13
#   1.66903646e-14  1.78221171e-14  6.44934062e-14  5.08964604e-14
#  -1.76774506e-14  2.48522269e-14  8.87740725e-14  1.16181127e-13
#   5.54473445e-14  6.41415454e-14  2.37250788e-13  1.35878508e-14
#   1.22043389e-13  9.96539029e-14 -1.47456944e-13  1.62480660e-13
#   1.65141785e-13 -3.80313736e-14  2.36190090e-14 -3.06087600e-14
#  -1.70157577e-14 -3.31152350e-14  1.04230935e-14  2.55694488e-14
#  -1.39143310e-13  2.39015208e-14  6.13732709e-14  1.35564164e-13
#  -3.96781275e-14 -5.32347144e-14  7.35701633e-14  3.32704531e-14
#  -1.77842594e-13 -5.83827386e-14 -2.03099262e-13 -5.95065330e-14
#  -8.54379323e-14 -3.41311193e-13 -9.96845984e-14 -8.19466095e-14
#  -8.38900860e-14  1.01085789e-13 -1.14387717e-13 -1.29939508e-13
#  -1.01695434e-13  7.25606242e-16  1.75305104e-14  2.98033598e-15
#   5.32022426e-15  9.35219902e-15 -2.41482923e-14  3.26851080e-14
#  -6.21079721e-14  3.33304229e-14  4.07015932e-14 -2.05668584e-13
#   3.66944732e-13  1.13979866e-13 -3.00275360e-14  2.63241873e-15
#  -1.57606337e-13 -6.74583589e-14 -5.22601340e-14  7.17108151e-14
#   8.32187652e-16  6.57655619e-14  4.21323421e-15 -9.18612386e-14
#  -1.28166562e-13  2.07197104e-14 -1.25987754e-14  9.53491508e-14
#   1.13848841e-14 -5.58218005e-14 -7.44692841e-14  5.22620169e-14
#   1.01936593e-14 -2.72661893e-14 -2.67049671e-14 -4.72734030e-14
#   2.25574581e-14  3.83406018e-14  3.86893362e-14  1.62436322e-13
#  -4.82145879e-14 -1.79281301e-14 -1.08366294e-14  2.57668944e-13
#   2.91800006e-14  4.64831373e-14 -4.24790869e-14 -1.26767645e-13
#  -1.41357646e-13  1.43868988e-13  6.96877578e-14 -2.18990408e-13
#   1.39392569e-13  5.89938054e-14  1.59038791e-13  9.77749437e-14
#  -5.13534815e-14  1.61876699e-13  5.56435964e-14 -7.31004235e-14
#  -1.98062899e-14 -7.42085504e-14 -2.00677164e-14  8.51328252e-14
#   1.60673608e-14  2.72683565e-14  2.68136660e-13 -1.14558247e-13
#   6.83922963e-14  7.02772240e-14  6.18092599e-14 -2.25091981e-13
#  -2.86319732e-13  1.52267603e-13  1.89850198e-13  1.24737198e-14
#  -4.88603291e-14 -1.64604899e-13  1.78665687e-13 -1.53527822e-13
#   3.18817683e-14 -6.43467502e-16 -5.19943910e-14 -7.01021463e-15
#   8.28458724e-14 -9.33788158e-14 -1.06126947e-13  3.53242058e-14
#  -2.79592349e-14  6.77140832e-14  2.92880742e-14  2.11741735e-14
#   5.42570433e-14 -1.00942543e-13  2.88781621e-14 -2.77827894e-14
#   9.74569048e-14 -2.61542255e-14  6.92887170e-14 -5.96293148e-14
#   7.82551979e-14 -2.65345079e-14  5.74436854e-14 -1.71921783e-13
#  -1.01693445e-13 -1.10114229e-13 -9.06356945e-14  2.19384901e-13
#   1.37134748e-13  5.85953330e-14  2.06495088e-14 -6.74680223e-14
#   3.38019390e-14 -4.41139036e-14 -1.01155138e-13  8.29203373e-17
#  -5.77878367e-14  8.90344154e-14 -1.57719171e-14  3.70192765e-15
#  -2.24562768e-14  8.02691602e-14  7.10087988e-15 -2.22426024e-13
#   6.81600909e-14  3.66054564e-14 -1.47491050e-13  7.96779887e-14
#   7.75310127e-14  4.32692104e-14  2.65060862e-14  4.34488356e-14
#   7.71859732e-14  1.04252535e-13 -5.19366949e-14 -2.17272600e-14
#   8.90747742e-14 -1.14838485e-13 -5.24514121e-14  7.12429937e-14
#  -1.83573832e-13  9.78207026e-14  3.49587026e-15  2.92543234e-14
#   2.21319851e-14 -1.16114052e-14  1.22815891e-14 -1.76615913e-13
#  -5.11857934e-14  4.52928361e-14 -1.89302796e-14 -1.93501819e-13
#   1.05075344e-13  1.74577508e-13  8.64713456e-14 -1.37865754e-13
#   2.96194003e-14  7.45944817e-14  4.16503099e-14  2.39115252e-13
#   1.51112545e-13  1.38231826e-14 -1.07315827e-13  2.62764388e-14
#   1.15950058e-13  1.07206688e-15  4.46095783e-14  4.00495992e-14
#   3.13048076e-14  6.03785111e-14  6.26079100e-14 -1.00467190e-14
#   2.87199953e-14  1.00665147e-13  8.82209861e-15  1.23765176e-14
#  -6.07457196e-14 -6.44956799e-14 -6.20192964e-14 -9.90598892e-14
#   6.17237106e-14  6.45172804e-14 -1.95518624e-14 -1.74941306e-13
#   2.07444373e-14 -1.94299332e-13  3.70278030e-14 -4.22585344e-14
#  -1.00271791e-15 -1.71166903e-14 -7.93613708e-14  8.10450729e-14
#   4.08499545e-14 -1.26445343e-13  8.38406322e-14 -7.34280547e-14
#   8.14537771e-14 -4.58601335e-14  1.56878741e-13 -4.70011940e-14
#  -4.54154758e-14  1.40105527e-13 -6.68782718e-14 -1.01260866e-13
#  -1.17589707e-13  1.12834186e-14  2.39316478e-14  6.99333214e-14
#  -1.10957217e-13 -1.12757448e-13  3.15685611e-14 -1.62947345e-14
#  -1.00677084e-13 -1.03506181e-14 -2.23155894e-14 -2.07644462e-13
#  -2.09570317e-14 -1.58474904e-13  1.41962460e-13 -7.85155407e-14
#  -5.14194198e-14  2.03143600e-13  1.64055791e-14 -5.69991698e-14
#   5.66399194e-14  5.95409233e-14  8.78617357e-14  8.90736374e-15
#  -1.13901422e-14  3.50965479e-14 -6.02001649e-14 -9.86997861e-14
#   6.02216232e-14  9.93168214e-15 -4.98465624e-14  2.01129069e-14
#   6.00869043e-14 -9.48807610e-14  3.99347755e-14  9.88541160e-14
#  -5.24210009e-14 -1.31204843e-13 -2.31489139e-14  1.06151674e-13
#   2.74258127e-14 -2.03405648e-13 -1.84122655e-13  2.27291821e-13
#  -1.63051936e-13  2.02231831e-14  4.10921075e-15 -4.36546088e-14
#   3.13818305e-14  8.21765411e-14 -2.19907292e-14  4.83575491e-14
#  -8.70073791e-15 -4.60218530e-14  2.59072408e-14  1.19285346e-13
#  -1.35351002e-13 -6.08875439e-14 -1.13058718e-13  2.01850980e-15
#  -1.94509653e-14 -4.79246864e-14 -1.04267883e-14 -2.36997266e-14
#   1.55004045e-13  1.39033318e-14  1.44202659e-13 -1.83149496e-14
#  -8.87735041e-14 -5.98788574e-14 -1.48779691e-13 -1.47001629e-13
#  -2.77259460e-14 -5.35081313e-14 -2.94335223e-14 -4.71374051e-15
#   6.72555700e-14  1.04819264e-13 -5.70344127e-14 -4.13731271e-14
#  -6.75299816e-15 -1.41028522e-15  7.50193863e-14  9.83800419e-14
#  -2.58751243e-15  1.24191502e-14 -1.16399974e-13 -2.04832418e-14
#  -5.66438985e-14 -2.22873382e-13 -1.21376615e-13 -1.79593371e-13
#  -2.21285745e-14  8.23217761e-14  1.38170435e-13 -1.43518832e-13
#  -8.44704573e-14 -6.30467412e-14 -1.84600140e-13  6.75282763e-14
#  -1.83825364e-13  2.95455038e-14 -1.34356526e-13  1.88020977e-14
#   2.13402984e-14 -1.79571202e-14 -8.45608383e-14 -8.88365292e-14
#  -1.77159620e-14 -3.56161678e-14 -7.61659180e-15  7.13498594e-14
#   4.62162575e-14 -8.11388645e-14 -2.06932782e-14  4.00228828e-14
#  -3.62192054e-14 -4.31634817e-14 -6.02938144e-14 -2.18540208e-14
#  -1.14979457e-13  1.10521228e-13  2.35885409e-13  1.39805820e-13
#  -5.22383061e-13  3.31903323e-13  3.06641823e-14  1.26725581e-13
#   6.97431801e-14  1.65796905e-13 -1.84854798e-14  1.86531679e-14
#  -9.85053816e-14 -1.73773174e-14 -3.51631968e-14  2.93866620e-14
#   6.87903068e-15  5.43538903e-14 -1.54717839e-14 -6.91088076e-15
#   7.65825803e-14 -1.94404493e-15 -6.13812290e-14 -3.52469556e-13
#   2.44062903e-14  1.11988925e-13  1.40567806e-13  4.54315341e-14
#  -6.84585189e-14 -1.38898031e-13 -2.51435495e-14 -3.48628078e-13
#  -9.97852112e-14 -3.21807647e-14 -1.75242860e-13 -2.75008460e-14
#   5.87661475e-14  9.59369117e-14  6.72184797e-14  5.09808729e-14
#   3.92344646e-14  9.35477829e-14 -1.56865099e-14 -1.50246926e-14
#   8.72311112e-15 -7.89771804e-15 -6.65296085e-14  1.57041313e-14
#  -6.26158680e-15  7.54926077e-14  7.77961873e-14  2.84063617e-13
#   2.72507350e-14 -2.79977712e-13 -9.62418767e-14 -4.75972683e-14
#  -1.25914426e-13 -2.12406235e-13 -2.93206881e-13 -2.03144168e-13
#   2.49492587e-13 -1.02799902e-13 -5.86987881e-14  1.53985980e-13
#  -1.04103890e-13 -1.97588008e-13  1.73639592e-14 -7.46402407e-14
#   2.12125428e-14 -6.76277523e-14 -2.01460892e-14 -1.95761451e-14
#  -6.97200520e-15  7.97637512e-16  2.67510814e-14 -4.47089121e-14
#   6.07451511e-14 -1.21696075e-14 -9.18475962e-15 -2.32512605e-13
#   3.50595997e-14 -1.41167220e-13 -2.85411943e-13 -2.09868176e-13
#   1.84332976e-13  5.71606051e-14 -1.89485831e-13 -2.87363946e-13
#   3.24467919e-14  9.87603244e-14 -2.10043822e-13 -1.44109435e-13
#   4.96841324e-14 -1.94847587e-13 -4.76759965e-14 -8.81098572e-14
#  -2.81998780e-14  8.43802894e-14  1.36699896e-14  9.68283231e-16
#  -9.48914280e-16  2.18719176e-14  2.17850982e-14 -4.79399631e-14
#   1.39292666e-13  1.85329725e-13  1.81313169e-13  1.59369904e-13
#  -4.42292958e-14 -3.29367253e-13 -4.83362328e-14 -2.61333071e-13
#   3.22870619e-14 -7.64401875e-14  2.84487669e-13 -5.84418558e-14
#  -2.10687290e-13 -2.19569074e-13  2.78477046e-13  1.31620936e-14
#  -8.18175749e-14  1.88074409e-13  1.94688710e-16 -5.34501510e-14
#  -4.41447412e-14  3.15279181e-14  5.09981390e-15 -3.70361519e-15
#  -2.81218618e-15 -1.33131617e-15  3.34492345e-14 -2.24048335e-14
#   5.79787951e-14 -1.85838616e-13 -1.49458401e-13  3.93353616e-14
#  -1.58074442e-14 -3.78160792e-14 -1.43413104e-14  1.31747413e-13
#  -3.06101526e-13  2.61363198e-14 -4.65082906e-13  3.46180116e-13
#   4.83328506e-13  2.51162646e-14  1.55287125e-13 -5.13799137e-14
#   3.53563223e-14 -2.78255641e-14 -1.82954807e-14 -2.04715889e-14
#  -1.17893251e-14 -1.69966974e-14 -8.87583784e-15 -5.47859258e-15] [1.00891972e-01 2.69670270e-01 8.00139186e-01 2.55808036e+00
#  4.30015781e+00 5.76577062e+00 8.23639711e+00 1.43421215e+01
#  2.39236625e+01 3.82343853e+01 5.77226660e+01 6.60764749e+01
#  6.86435772e+01 6.79584697e+01 6.74349322e+01 6.95260658e+01
#  6.78337014e+01 6.26790760e+01 5.16589916e+01 3.25967961e+01
#  2.02429863e+01 1.41409340e+01 1.05690440e+01 8.93681072e+00
#  6.63232467e+00 4.94684217e+00 2.87524393e+00 1.17519988e+00
#  6.16908421e-01 1.47170123e+00 3.18249758e+00 6.57218776e+00
#  9.83107762e+00 1.58052057e+01 2.99597185e+01 4.80430249e+01
#  6.54030326e+01 8.20169677e+01 9.53594497e+01 9.99240711e+01
#  1.03558874e+02 1.02714460e+02 1.02197090e+02 1.03585367e+02
#  1.01424377e+02 9.68456433e+01 9.17784600e+01 7.57163088e+01
#  5.90962756e+01 4.29947625e+01 2.96876653e+01 2.32304155e+01
#  1.84001415e+01 1.32822578e+01 8.11170781e+00 2.98981401e+00
#  1.84081350e+00 3.37249763e+00 5.82188999e+00 9.60488064e+00
#  1.62632526e+01 3.51291935e+01 5.68470508e+01 6.91506375e+01
#  7.84559006e+01 8.66679821e+01 9.43995355e+01 9.45186051e+01
#  9.57276613e+01 9.72271914e+01 9.81154452e+01 9.66074739e+01
#  9.40118414e+01 9.29192849e+01 9.15962774e+01 8.37063978e+01
#  7.61809535e+01 6.76066564e+01 5.20764718e+01 3.62205232e+01
#  2.77175561e+01 1.99915719e+01 1.28736203e+01 4.54645057e+00
#  2.52247973e+00 5.55455341e+00 8.39894751e+00 1.37141211e+01
#  2.77786841e+01 5.24613864e+01 6.83970278e+01 7.72332051e+01
#  8.49446186e+01 9.01375072e+01 9.43104052e+01 9.31614038e+01
#  9.44157689e+01 9.56443471e+01 9.58189617e+01 9.43928133e+01
#  9.23936795e+01 9.16963701e+01 9.22373243e+01 8.80906099e+01
#  8.37928740e+01 7.69689186e+01 6.73613858e+01 5.08475088e+01
#  3.70635636e+01 2.70446990e+01 1.81186820e+01 6.87493001e+00
#  2.99604426e+00 8.22697641e+00 1.24276323e+01 2.01245195e+01
#  3.96761258e+01 6.21969086e+01 7.71046473e+01 8.40474307e+01
#  8.79882572e+01 9.05931001e+01 9.34571354e+01 9.20116810e+01
#  9.31094115e+01 9.39046440e+01 9.38743478e+01 9.28314768e+01
#  9.10347745e+01 9.04723449e+01 9.08617741e+01 8.91617651e+01
#  8.83822477e+01 8.48088979e+01 7.61135830e+01 6.20511855e+01
#  4.69967492e+01 3.49292327e+01 2.41726143e+01 9.29556980e+00
#  5.09545802e+00 1.26212248e+01 1.80678360e+01 2.78614595e+01
#  4.92503331e+01 7.00390093e+01 8.26190398e+01 8.65749879e+01
#  8.91937781e+01 9.08258439e+01 9.25600296e+01 9.10788967e+01
#  9.16862769e+01 9.22514288e+01 9.22323511e+01 9.11663471e+01
#  8.92852328e+01 8.87569412e+01 8.95423157e+01 8.92108476e+01
#  9.01430151e+01 8.85994333e+01 8.31263644e+01 7.13957432e+01
#  5.77856301e+01 4.49354765e+01 3.18919738e+01 1.19584077e+01
#  6.84778747e+00 1.64590768e+01 2.35038144e+01 3.61315814e+01
#  5.69546577e+01 7.55598894e+01 8.59986763e+01 8.89252958e+01
#  9.03419035e+01 9.05713051e+01 9.13848984e+01 9.02438624e+01
#  9.08080211e+01 9.12795549e+01 9.11675296e+01 8.98345651e+01
#  8.73635128e+01 8.66108507e+01 8.76822323e+01 8.86947280e+01
#  9.13015965e+01 9.11860736e+01 8.75066550e+01 7.79581505e+01
#  6.67700026e+01 5.48581349e+01 3.88474395e+01 1.47202474e+01
#  9.04236021e+00 2.07439021e+01 2.85812599e+01 4.24232113e+01
#  6.24485917e+01 7.96141415e+01 8.87148977e+01 9.15202123e+01
#  9.13037059e+01 9.02506017e+01 9.08457491e+01 8.98644319e+01
#  9.02990339e+01 9.01455068e+01 8.91097688e+01 8.84253162e+01
#  8.50902443e+01 8.40928543e+01 8.56846207e+01 8.80091319e+01
#  9.21219290e+01 9.29661332e+01 9.04114502e+01 8.27478920e+01
#  7.34683491e+01 6.30936468e+01 4.44722480e+01 1.67827591e+01
#  1.05002650e+01 2.41488248e+01 3.28269140e+01 4.71186920e+01
#  6.60671960e+01 8.22811182e+01 9.04061340e+01 9.42320342e+01
#  9.29962535e+01 9.03957810e+01 9.07866773e+01 8.94848296e+01
#  8.99745259e+01 8.88113871e+01 8.62928423e+01 8.55274837e+01
#  8.12185995e+01 8.03532127e+01 8.40289046e+01 8.75252643e+01
#  9.32326359e+01 9.43512598e+01 9.23146638e+01 8.64221421e+01
#  7.85420582e+01 6.98086375e+01 5.05012463e+01 1.92627998e+01
#  1.15579080e+01 2.73991153e+01 3.54321764e+01 4.99942666e+01
#  6.85748238e+01 8.44440393e+01 9.16365597e+01 9.58884769e+01
#  9.44315154e+01 9.08341789e+01 9.08214285e+01 8.93449777e+01
#  8.94867062e+01 8.68311554e+01 8.35141458e+01 8.03295670e+01
#  7.57696022e+01 7.59820693e+01 8.23543578e+01 8.72670531e+01
#  9.38947624e+01 9.49138374e+01 9.34109501e+01 8.88374251e+01
#  8.22968869e+01 7.55999862e+01 5.64394996e+01 2.16773797e+01
#  1.33887281e+01 3.03241405e+01 3.71849083e+01 5.08876643e+01
#  6.95881141e+01 8.57176258e+01 9.18766785e+01 9.61293139e+01
#  9.49602613e+01 9.13316134e+01 9.04447607e+01 8.82404090e+01
#  8.71775797e+01 8.29771849e+01 8.08418414e+01 7.57642722e+01
#  7.27169914e+01 7.30685631e+01 7.98963359e+01 8.64775417e+01
#  9.35576611e+01 9.47376330e+01 9.37057257e+01 8.99998461e+01
#  8.49174062e+01 8.10034868e+01 6.36488981e+01 2.41477877e+01
#  1.49322344e+01 3.24852242e+01 3.83656918e+01 5.06970324e+01
#  6.91730041e+01 8.56156466e+01 9.13267520e+01 9.55484971e+01
#  9.44450532e+01 9.07041948e+01 8.80433603e+01 8.47126512e+01
#  8.30376705e+01 7.99179003e+01 7.93497634e+01 7.35704603e+01
#  7.14682280e+01 7.14259892e+01 7.72238058e+01 8.47119918e+01
#  9.17325744e+01 9.37627788e+01 9.34335114e+01 9.10318645e+01
#  8.64558944e+01 8.46657288e+01 7.07918564e+01 2.60893003e+01
#  1.63516111e+01 3.42333086e+01 3.94531880e+01 5.16812321e+01
#  6.97078772e+01 8.58781222e+01 9.10761492e+01 9.46118871e+01
#  9.27053313e+01 8.85705558e+01 8.47075818e+01 8.14130688e+01
#  7.95731128e+01 7.77936589e+01 7.86710033e+01 7.25915865e+01
#  7.07603787e+01 7.06730985e+01 7.51996658e+01 8.35966902e+01
#  9.03501449e+01 9.34474399e+01 9.38283871e+01 9.24344012e+01
#  8.80658697e+01 8.66945295e+01 7.68358701e+01 2.82649035e+01
#  1.79889373e+01 3.60557202e+01 4.12849559e+01 5.36676703e+01
#  7.16246760e+01 8.71192547e+01 9.16626485e+01 9.39298036e+01
#  9.10950936e+01 8.70730708e+01 8.23602782e+01 7.84524283e+01
#  7.66348474e+01 7.66518076e+01 7.86933334e+01 7.24881953e+01
#  7.05214747e+01 7.05950077e+01 7.39784318e+01 8.30791088e+01
#  9.02326688e+01 9.41608752e+01 9.47117329e+01 9.31204812e+01
#  8.88892438e+01 8.73800648e+01 8.15929067e+01 3.14479767e+01
#  2.03703043e+01 4.18028060e+01 4.75275594e+01 5.92359911e+01
#  7.57708355e+01 8.92673366e+01 9.28337976e+01 9.36747695e+01
#  8.96729240e+01 8.55227723e+01 7.98129543e+01 7.54424767e+01
#  7.39634661e+01 7.60722728e+01 7.90118091e+01 7.26013793e+01
#  7.01122742e+01 6.96392781e+01 7.28030311e+01 8.24674057e+01
#  8.98669011e+01 9.42727112e+01 9.47205908e+01 9.31624799e+01
#  8.88543325e+01 8.72779636e+01 8.44321339e+01 3.47683336e+01
#  2.52850853e+01 5.23783057e+01 5.67341795e+01 6.61575676e+01
#  7.97966529e+01 9.05349115e+01 9.32267716e+01 9.26299936e+01
#  8.80533851e+01 8.33524632e+01 7.61084569e+01 7.17378836e+01
#  7.20396473e+01 7.55774898e+01 7.91376136e+01 7.24469574e+01
#  6.93474197e+01 6.83719213e+01 7.16028078e+01 8.15603431e+01
#  8.93322662e+01 9.45343501e+01 9.49923589e+01 9.31700474e+01
#  8.93597659e+01 8.77312317e+01 8.67542516e+01 3.76320936e+01
#  2.94819147e+01 5.81124712e+01 6.12359119e+01 6.99786302e+01
#  8.18689606e+01 9.07659418e+01 9.34392209e+01 9.18362587e+01
#  8.68194123e+01 8.09174650e+01 7.26457453e+01 6.91673550e+01
#  7.06809231e+01 7.53318179e+01 7.91656456e+01 7.18520229e+01
#  6.76437491e+01 6.68639972e+01 7.07678057e+01 8.11031656e+01
#  8.91842127e+01 9.49416805e+01 9.49942847e+01 9.29132879e+01
#  8.90795393e+01 8.70117896e+01 8.65650171e+01 3.75172657e+01
#  2.93123844e+01 5.90514375e+01 6.34030387e+01 7.18438557e+01
#  8.29460160e+01 9.10629913e+01 9.36134570e+01 9.07540194e+01
#  8.59242649e+01 7.93802779e+01 7.08506154e+01 6.83110162e+01
#  6.99860960e+01 7.53985192e+01 7.89697567e+01 7.18392032e+01
#  6.73552481e+01 6.72021021e+01 7.23468919e+01 8.23373685e+01
#  8.90714686e+01 9.48664096e+01 9.48743900e+01 9.21220204e+01
#  8.75908145e+01 8.47452591e+01 8.38204673e+01 3.54601611e+01
#  2.64640681e+01 5.78483640e+01 6.42356558e+01 7.22268852e+01
#  8.28379528e+01 9.05446947e+01 9.32830448e+01 8.96138252e+01
#  8.57203226e+01 7.99073803e+01 7.19013336e+01 7.00491789e+01
#  7.18220833e+01 7.73892515e+01 8.06030363e+01 7.45732356e+01
#  7.06197796e+01 7.10016870e+01 7.61771752e+01 8.47552260e+01
#  8.90964019e+01 9.46117851e+01 9.49272800e+01 9.15343505e+01
#  8.61765164e+01 8.27595888e+01 8.10584557e+01 3.37414771e+01
#  2.51244948e+01 5.69486826e+01 6.39221672e+01 7.24207752e+01
#  8.31334843e+01 9.07841787e+01 9.33350550e+01 8.89840683e+01
#  8.65921331e+01 8.17402375e+01 7.46045173e+01 7.35631713e+01
#  7.49108433e+01 7.96867534e+01 8.25916229e+01 7.72675186e+01
#  7.40759231e+01 7.48631295e+01 7.95717647e+01 8.64625184e+01
#  8.88656558e+01 9.40242249e+01 9.48390499e+01 9.08180986e+01
#  8.46468377e+01 8.06031531e+01 7.68617475e+01 3.01629475e+01
#  2.52880639e+01 5.63659052e+01 6.33175347e+01 7.22760682e+01
#  8.35317680e+01 9.15304809e+01 9.39953949e+01 8.92809340e+01
#  8.84993120e+01 8.48090793e+01 7.87186806e+01 7.79913083e+01
#  7.90782064e+01 8.31481504e+01 8.58670521e+01 8.20422768e+01
#  8.03571108e+01 8.13444393e+01 8.45506208e+01 8.92670940e+01
#  8.92924007e+01 9.35943074e+01 9.50595397e+01 9.00835881e+01
#  8.23201972e+01 7.68804213e+01 7.08989954e+01 2.73134838e+01
#  2.38852534e+01 5.41390381e+01 6.14566425e+01 7.12391660e+01
#  8.32761964e+01 9.21784468e+01 9.46904702e+01 8.99084905e+01
#  9.09713871e+01 8.88311927e+01 8.38645083e+01 8.34683708e+01
#  8.44440446e+01 8.74834399e+01 8.97339470e+01 8.71546455e+01
#  8.63735356e+01 8.71890786e+01 8.91630493e+01 9.16675908e+01
#  8.97421870e+01 9.32879088e+01 9.54239423e+01 8.95691513e+01
#  8.03457577e+01 7.33765505e+01 6.61900408e+01 2.57004194e+01
#  2.15507177e+01 4.87619347e+01 5.68505147e+01 6.78080452e+01
#  8.14116139e+01 9.11547397e+01 9.36957023e+01 8.89118313e+01
#  9.20650482e+01 9.10919670e+01 8.71945797e+01 8.70966558e+01
#  8.77520459e+01 9.01080276e+01 9.19012908e+01 9.05241018e+01
#  9.05494513e+01 9.10500831e+01 9.12842659e+01 9.26451364e+01
#  8.85473842e+01 9.08569910e+01 9.38551769e+01 8.72829678e+01
#  7.66846183e+01 6.79954914e+01 5.91309210e+01 2.19954797e+01
#  1.79525238e+01 4.19603132e+01 5.13014266e+01 6.36355930e+01
#  7.88579364e+01 8.97711391e+01 9.20221102e+01 8.76290657e+01
#  9.28098157e+01 9.32933901e+01 9.07589908e+01 9.09882347e+01
#  9.16083497e+01 9.29505737e+01 9.40738073e+01 9.33489548e+01
#  9.36515025e+01 9.35259975e+01 9.28154517e+01 9.31899974e+01
#  8.68372452e+01 8.79118251e+01 9.17670956e+01 8.45361431e+01
#  7.23896953e+01 6.17763697e+01 5.12767637e+01 1.84027388e+01
#  1.38230760e+01 3.30342851e+01 4.40516329e+01 5.82355123e+01
#  7.51797421e+01 8.71433451e+01 8.86798995e+01 8.46870435e+01
#  9.20149419e+01 9.41122512e+01 9.28978961e+01 9.37390660e+01
#  9.40916449e+01 9.45312322e+01 9.48450681e+01 9.45655418e+01
#  9.53476456e+01 9.49601429e+01 9.29542889e+01 9.20996986e+01
#  8.42983760e+01 8.40023085e+01 8.88312162e+01 8.14822393e+01
#  6.75250657e+01 5.48795437e+01 4.29737894e+01 1.52678965e+01
#  9.49717274e+00 2.45318926e+01 3.63008071e+01 5.16725194e+01
#  7.06546371e+01 8.40167670e+01 8.48243440e+01 8.05353112e+01
#  8.99404030e+01 9.35980145e+01 9.34341034e+01 9.48085776e+01
#  9.48803997e+01 9.41541029e+01 9.35568313e+01 9.37271876e+01
#  9.50991640e+01 9.47090993e+01 9.20026136e+01 9.01093172e+01
#  8.09673261e+01 7.97305291e+01 8.53050238e+01 7.74954593e+01
#  6.10253187e+01 4.62997595e+01 3.37558571e+01 1.20939468e+01
#  4.90105174e+00 1.53111436e+01 2.69807230e+01 4.49530695e+01
#  6.66473858e+01 8.14169870e+01 8.24137955e+01 7.81645234e+01
#  8.77603650e+01 9.46354755e+01 9.81450605e+01 1.01166402e+02
#  1.01569404e+02 9.98044704e+01 9.79840972e+01 9.92429279e+01
#  1.01006888e+02 9.98712879e+01 9.51832267e+01 8.87646021e+01
#  7.83943391e+01 7.70523498e+01 8.31628180e+01 7.42414806e+01
#  5.57174453e+01 3.73813516e+01 2.41935195e+01 7.93930463e+00
#  1.00153522e+00 4.55419708e+00 9.98518085e+00 2.07401891e+01
#  3.67193383e+01 4.85842166e+01 4.80595266e+01 4.19873842e+01
#  4.81044729e+01 5.48153747e+01 6.20804689e+01 6.84876644e+01
#  6.97281785e+01 6.74333973e+01 6.62210723e+01 6.66440756e+01
#  6.85552846e+01 6.60263794e+01 5.74277078e+01 4.88145063e+01
#  4.19239655e+01 4.37398837e+01 5.18876352e+01 4.51179009e+01
#  2.93844596e+01 1.71437213e+01 8.97387492e+00 2.16591823e+00]
# The training accuracy is given by: 79.930000

# %% [markdown]
# ### Validating SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_fashion)))
# Out:
# The validation accuracy is given by: 83.360000

# %% [markdown]
# ### Testing SVM on Fashion-MNIST

# %%
pred_svm = svm_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_fashion)))
# Out:
# The testing accuracy is given by: 82.390000

# %% [markdown]
# ## Training SVM on Rice

# %%
lr = 10
n_epochs = 100
reg_const = 0.05

svm_RICE = SVM(n_class_RICE, lr, n_epochs, reg_const)
svm_RICE.train(X_train_RICE, y_train_RICE)

# %%
pred_svm = svm_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_svm, y_train_RICE)))
# Out:
# [9.07444249e+03 7.03448162e+03 1.51576574e+02 5.98266212e+01
#  9.15265746e-01 7.22367583e+03 9.41168016e+01 6.17015225e-01
#  3.51401456e+02 7.08531504e-01 2.59654709e+00] [5.24631569e+03 1.46923665e+03 1.23794485e+01 1.00769117e+01
#  3.04533391e-02 1.50426748e+03 9.93014817e+00 1.04110300e-01
#  2.95615195e+01 6.71161928e-02 4.34237337e-01]
# The training accuracy is given by: 99.935845

# %% [markdown]
# ### Validating SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_svm, y_val_RICE)))
# Out:
# [9.07444249e+03 7.03448162e+03 1.51576574e+02 5.98266212e+01
#  9.15265746e-01 7.22367583e+03 9.41168016e+01 6.17015225e-01
#  3.51401456e+02 7.08531504e-01 2.59654709e+00] [5.24631569e+03 1.46923665e+03 1.23794485e+01 1.00769117e+01
#  3.04533391e-02 1.50426748e+03 9.93014817e+00 1.04110300e-01
#  2.95615195e+01 6.71161928e-02 4.34237337e-01]
# The validation accuracy is given by: 99.890019

# %% [markdown]
# ### Testing SVM on Rice

# %%
pred_svm = svm_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_svm, y_test_RICE)))
# Out:
# [9.07444249e+03 7.03448162e+03 1.51576574e+02 5.98266212e+01
#  9.15265746e-01 7.22367583e+03 9.41168016e+01 6.17015225e-01
#  3.51401456e+02 7.08531504e-01 2.59654709e+00] [5.24631569e+03 1.46923665e+03 1.23794485e+01 1.00769117e+01
#  3.04533391e-02 1.50426748e+03 9.93014817e+00 1.04110300e-01
#  2.95615195e+01 6.71161928e-02 4.34237337e-01]
# The testing accuracy is given by: 99.945010

# %% [markdown]
# # Softmax Classifier (with SGD)

# %% [markdown]
# ## Training Softmax on Fashion-MNIST

# %%
lr = 0.5
n_epochs = 50
reg_const = 0.5

softmax_fashion = Softmax(n_class_fashion, lr, n_epochs, reg_const)
softmax_fashion.train(X_train_fashion, y_train_fashion)

# %%
pred_softmax = softmax_fashion.predict(X_train_fashion)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_fashion)))
# Out:
# The training accuracy is given by: 83.962000

# %% [markdown]
# ### Validating Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_val_fashion)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_fashion)))
# Out:
# The validation accuracy is given by: 83.050000

# %% [markdown]
# ### Testing Softmax on Fashion-MNIST

# %%
pred_softmax = softmax_fashion.predict(X_test_fashion)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_fashion)))
# Out:
# The testing accuracy is given by: 82.420000

# %% [markdown]
# ### Training Softmax on Rice

# %%
lr = 1
n_epochs = 10
reg_const = 0.5

softmax_RICE = Softmax(n_class_RICE, lr, n_epochs, reg_const)
softmax_RICE.train(X_train_RICE, y_train_RICE)

# %%
pred_softmax = softmax_RICE.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_softmax, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.615067

# %% [markdown]
# ### Validating Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_softmax, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.450096

# %% [markdown]
# ### Testing Softmax on Rice

# %%
pred_softmax = softmax_RICE.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_softmax, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.752543

# %% [markdown]
# # Logistic Classifier

# %% [markdown]
# ### Training Logistic Classifer

# %%
learning_rate = 0.3
n_epochs = 20
threshold = 0.5

lr = Logistic(learning_rate, n_epochs, threshold)
lr.train(X_train_RICE, y_train_RICE)

# %%
pred_lr = lr.predict(X_train_RICE)
print('The training accuracy is given by: %f' % (get_acc(pred_lr, y_train_RICE)))
# Out:
# The training accuracy is given by: 99.780038

# %% [markdown]
# ### Validating Logistic Classifer

# %%
pred_lr = lr.predict(X_val_RICE)
print('The validation accuracy is given by: %f' % (get_acc(pred_lr, y_val_RICE)))
# Out:
# The validation accuracy is given by: 99.587572

# %% [markdown]
# ### Testing Logistic Classifier

# %%
pred_lr = lr.predict(X_test_RICE)
print('The testing accuracy is given by: %f' % (get_acc(pred_lr, y_test_RICE)))
# Out:
# The testing accuracy is given by: 99.725048
